# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth',800)

#Offre d'emploie
pd.read_csv("Offres d'emploi (1).csv",header=0)
# Out:
#     NB_VACANCIES_CREATION STATUS_CODE STATUS_NAME EXPERIENCE_CODE  \
# 0                       1          EC    En cours               D
# 1                       1          EC    En cours               E
# 2                       1          EC    En cours               E
# 3                       1          EC    En cours               D
# 4                       1          EC    En cours               E
# ..                    ...         ...         ...             ...
# 95                      1          EC    En cours               D
# 96                      1          EC    En cours               E
# 97                      1          EC    En cours               E
# 98                      1          EC    En cours               E
# 99                      1          EC    En cours               E
#
#       EXPERIENCE_NAME  EXPERIENCE_MIN_DURATION  EXPERIENCE_MAX_DURATION  \
# 0    Débutant accepté                      NaN                      NaN
# ...
